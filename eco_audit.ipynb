# %% [markdown]
# # 导入库并加载数据

# %%
import pandas as pd
import numpy as np

# 加载 CSV 文件
df = pd.read_csv("./data/城市_20220101-20221231/china_cities_20220102.csv")

# 查看数据的基本信息
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Columns: 378 entries, date to 西咸新区
# dtypes: float64(375), int64(2), object(1)
# memory usage: 1.0+ MB
#        date  hour       type    北京     天津    石家庄     唐山    秦皇岛     邯郸    保定  \
# 0  20220102     0        AQI  17.0   17.0  103.0   33.0   51.0  174.0  54.0
# 1  20220102     0      PM2.5   6.0    5.0   77.0   10.0   18.0  132.0  18.0
# 2  20220102     0  PM2.5_24h  24.0   71.0   61.0   67.0   69.0  114.0  53.0
# 3  20220102     0       PM10  15.0   15.0  135.0   33.0   51.0  179.0  58.0
# 4  20220102     0   PM10_24h  54.0  117.0  109.0  121.0  113.0  151.0  92.0
#
#    ...  塔城地区  阿勒泰地区    石河子    五家渠  三沙   兰州新区   赣江新区    儋州   雄安新区   西咸新区
# 0  ...  52.0   22.0  173.0  394.0 NaN  116.0   84.0  51.0   50.0  235.0
# 1  ...  29.0   10.0  131.0  292.0 NaN   88.0   62.0  30.0    8.0  185.0
# 2  ...  17.0    7.0  151.0  265.0 NaN   55.0   56.0  22.0   58.0  130.0
# 3  ...  54.0    2.0  247.0  495.0 NaN  147.0  113.0  52.0   50.0  181.0
# 4  ...  35.0    7.0  277.0  443.0 NaN   95.0  118.0  43.0  121.0  126.0
#
# [5 rows x 378 columns]

# %% [markdown]
# # 检测异常值

# %% [markdown]
# 常见的异常值检测方法包括：
#
# IQR（四分位距）法：基于数据的四分位数计算，异常值定义为超出1.5倍IQR范围的点。
# Z-score法：基于标准差，通常定义为与均值相差超过3个标准差的点为异常值。
# IQR 方法的实现：

# %%
def detect_outliers_iqr(df, columns):
    outliers = pd.DataFrame(False, index=df.index, columns=columns)
    for col in columns:
        if df[col].dtype in ['float64', 'int64']:  # 只检测数值型列
            Q1 = df[col].quantile(0.25)
            Q3 = df[col].quantile(0.75)
            IQR = Q3 - Q1
            lower_bound = Q1 - 1.5 * IQR
            upper_bound = Q3 + 1.5 * IQR
            # 标记异常值
            outliers[col] = (df[col] < lower_bound) | (df[col] > upper_bound)
    return outliers

# %% [markdown]
# # 应用异常值检测并标记

# %% [markdown]
# 选择需要检测的数值列，并应用异常值检测方法，然后为数据集添加一个标记列。

# %%
# 选择数值列
numeric_columns = df.select_dtypes(include=['float64', 'int64']).columns

# 检测异常值
outliers = detect_outliers_iqr(df, numeric_columns)

# 添加列标记异常值
df['has_outliers'] = outliers.any(axis=1)

# 查看标记后的数据
df.head()
# Out:
#        date  hour       type    北京     天津    石家庄     唐山    秦皇岛     邯郸    保定  \
# 0  20220102     0        AQI  17.0   17.0  103.0   33.0   51.0  174.0  54.0
# 1  20220102     0      PM2.5   6.0    5.0   77.0   10.0   18.0  132.0  18.0
# 2  20220102     0  PM2.5_24h  24.0   71.0   61.0   67.0   69.0  114.0  53.0
# 3  20220102     0       PM10  15.0   15.0  135.0   33.0   51.0  179.0  58.0
# 4  20220102     0   PM10_24h  54.0  117.0  109.0  121.0  113.0  151.0  92.0
#
#    ...  阿勒泰地区    石河子    五家渠  三沙   兰州新区   赣江新区    儋州   雄安新区   西咸新区  \
# 0  ...   22.0  173.0  394.0 NaN  116.0   84.0  51.0   50.0  235.0
# 1  ...   10.0  131.0  292.0 NaN   88.0   62.0  30.0    8.0  185.0
# 2  ...    7.0  151.0  265.0 NaN   55.0   56.0  22.0   58.0  130.0
# 3  ...    2.0  247.0  495.0 NaN  147.0  113.0  52.0   50.0  181.0
# 4  ...    7.0  277.0  443.0 NaN   95.0  118.0  43.0  121.0  126.0
#
#    has_outliers
# 0          True
# 1         False
# 2          True
# 3          True
# 4          True
#
# [5 rows x 379 columns]

# %% [markdown]
# # 分析结果

# %% [markdown]
# 可以统计异常值的数量，并进一步分析包含异常值的记录。

# %%
# 统计包含异常值的行数
outlier_count = df['has_outliers'].value_counts()
print(outlier_count)

# 显示部分包含异常值的记录
df_with_outliers = df[df['has_outliers']]
df_with_outliers.head()
# Out:
# has_outliers
# False    221
# True     139
# Name: count, dtype: int64
#        date  hour       type    北京     天津    石家庄     唐山    秦皇岛     邯郸    保定  \
# 0  20220102     0        AQI  17.0   17.0  103.0   33.0   51.0  174.0  54.0
# 2  20220102     0  PM2.5_24h  24.0   71.0   61.0   67.0   69.0  114.0  53.0
# 3  20220102     0       PM10  15.0   15.0  135.0   33.0   51.0  179.0  58.0
# 4  20220102     0   PM10_24h  54.0  117.0  109.0  121.0  113.0  151.0  92.0
# 5  20220102     0        SO2   2.0    5.0   12.0    3.0    4.0   22.0   5.0
#
#    ...  阿勒泰地区    石河子    五家渠  三沙   兰州新区   赣江新区    儋州   雄安新区   西咸新区  \
# 0  ...   22.0  173.0  394.0 NaN  116.0   84.0  51.0   50.0  235.0
# 2  ...    7.0  151.0  265.0 NaN   55.0   56.0  22.0   58.0  130.0
# 3  ...    2.0  247.0  495.0 NaN  147.0  113.0  52.0   50.0  181.0
# 4  ...    7.0  277.0  443.0 NaN   95.0  118.0  43.0  121.0  126.0
# 5  ...    1.0    6.0    2.0 NaN   30.0    8.0   4.0    6.0   11.0
#
#    has_outliers
# 0          True
# 2          True
# 3          True
# 4          True
# 5          True
#
# [5 rows x 379 columns]

# %% [markdown]
# # 保存处理后的数据

# %% [markdown]
# 最后，将处理后的数据保存到一个新的 CSV 文件中，以备后续使用。

# %%
# 保存标记了异常值的数据
df.to_csv("china_cities_with_outliers.csv", index=False)
